# %%
import requests
from pprint import pprint
import pandas as pd
import time
import json
import random
from sqlalchemy import create_engine

# %% [markdown]
# ## JSON requests for SY data

# %%
SY2016_resp = requests.get("https://data.cityofchicago.org/resource/fvrx-esxp.json")
SY2016_list = json.loads(SY2016_resp.text)
SY2016 = pd.DataFrame(SY2016_list)
list(SY2016.columns)
# Out:
# ['school_id',
#  'short_name',
#  'long_name',
#  'school_type',
#  'primary_category',
#  'address',
#  'city',
#  'state',
#  'zip',
#  'phone',
#  'fax',
#  'cps_school_profile',
#  'progress_report_year',
#  'empty_progress_report_message',
#  'school_latitude',
#  'school_longitude',
#  'location',
#  ':@computed_region_rpca_8um6',
#  ':@computed_region_vrxf_vc4k',
#  ':@computed_region_6mkv_f3dw',
#  ':@computed_region_bdys_3d7i',
#  ':@computed_region_43wa_7qmu',
#  'website',
#  'improvement_award_year',
#  'student_growth_rating',
#  'student_growth_description',
#  'student_attainment_rating',
#  'student_attainment_description',
#  'culture_climate_rating',
#  'culture_climate_description',
#  'school_survey_student_response_rate_pct',
#  'school_survey_student_response_rate_avg_pct',
#  'school_survey_teacher_response_rate_pct',
#  'school_survey_teacher_response_rate_avg_pct',
#  'healthy_school_certification',
#  'healthy_school_certification_description',
# ...

# %%
SY2016 = SY2016[["school_id","short_name", "school_type", "primary_category", "address", "city", "state", "zip", "phone", 
                "progress_report_year", "student_growth_rating", "student_attainment_rating", "growth_reading_grades_tested_pct_es",
                 "growth_math_grades_tested_pct_es", "attainment_reading_pct_es", "attainment_math_pct_es", "culture_climate_rating", "school_survey_involved_families",
                  "school_survey_supportive_environment", "school_survey_ambitious_instruction", "school_survey_effective_leaders", "school_survey_collaborative_teachers", 
                  "school_survey_safety", "suspensions_per_100_students_avg_pct", "student_attendance_avg_pct", "mobility_rate_pct", "one_year_dropout_rate_avg_pct",
                  "freshmen_on_track_school_pct_year_1", "college_enrollment_school_pct_year_1", "college_persistence_school_pct_year_2",
                   "teacher_attendance_avg_pct","school_latitude", "school_longitude"]]

SY2016["year"]= "2015-16"
len(SY2016)
# Out:
# 670

# %%
SY2017_resp = requests.get("https://data.cityofchicago.org/resource/cp7s-7gxg.json")
SY2017_list = json.loads(SY2017_resp.text)
SY2017 = pd.DataFrame(SY2017_list)
list(SY2017.columns)
# Out:
# ['school_id',
#  'short_name',
#  'long_name',
#  'school_type',
#  'primary_category',
#  'address',
#  'city',
#  'state',
#  'zip',
#  'phone',
#  'fax',
#  'cps_school_profile',
#  'website',
#  'progress_report_year',
#  'excelerate_award_gold_year',
#  'student_growth_rating',
#  'student_growth_description',
#  'growth_reading_grades_tested_pct_es',
#  'growth_reading_grades_tested_label_es',
#  'growth_math_grades_tested_pct_es',
#  'growth_math_grades_tested_label_es',
#  'student_attainment_rating',
#  'student_attainment_description',
#  'attainment_reading_pct_es',
#  'attainment_reading_lbl_es',
#  'attainment_math_pct_es',
#  'attainment_math_lbl_es',
#  'culture_climate_rating',
#  'culture_climate_description',
#  'school_survey_student_response_rate_pct',
#  'school_survey_student_response_rate_avg_pct',
#  'school_survey_teacher_response_rate_pct',
#  'school_survey_teacher_response_rate_avg_pct',
#  'healthy_school_certification',
# ...

# %%
SY2017 = SY2017[["school_id","short_name", "school_type", "primary_category", "address", "city", "state", "zip", "phone", 
                 "website", "progress_report_year", "student_growth_rating", "student_attainment_rating", "growth_reading_grades_tested_pct_es",
                 "growth_math_grades_tested_pct_es", "attainment_reading_pct_es", "attainment_math_pct_es", "culture_climate_rating", 
                 "school_survey_involved_families", "school_survey_supportive_environment", "school_survey_ambitious_instruction", 
                 "school_survey_effective_leaders", "school_survey_collaborative_teachers", "school_survey_safety", 
                 "suspensions_per_100_students_avg_pct", "student_attendance_avg_pct", "mobility_rate_pct", "one_year_dropout_rate_year_1_pct",
                 "freshmen_on_track_school_pct_year_1", "college_enrollment_school_pct_year_1", "college_persistence_school_pct_year_2",
                 "teacher_attendance_avg_pct","school_latitude", "school_longitude"]]
SY2017["year"]= "2016-17"
len(SY2017)
# Out:
# 661

# %%
SY2018_resp = requests.get("https://data.cityofchicago.org/resource/wkiz-8iya.json")
SY2018_list = json.loads(SY2018_resp.text)
SY2018 = pd.DataFrame(SY2018_list)
list(SY2018.columns)
# Out:
# ['school_id',
#  'short_name',
#  'long_name',
#  'school_type',
#  'primary_category',
#  'phone',
#  'fax',
#  'cps_school_profile',
#  'website',
#  'progress_report_year',
#  'student_growth_rating',
#  'student_growth_description',
#  'growth_reading_grades_tested_pct_es',
#  'growth_reading_grades_tested_label_es',
#  'growth_math_grades_tested_pct_es',
#  'growth_math_grades_tested_label_es',
#  'student_attainment_rating',
#  'student_attainment_description',
#  'attainment_reading_pct_es',
#  'attainment_reading_lbl_es',
#  'attainment_math_pct_es',
#  'attainment_math_lbl_es',
#  'culture_climate_rating',
#  'culture_climate_description',
#  'school_survey_student_response_rate_pct',
#  'school_survey_student_response_rate_avg_pct',
#  'school_survey_teacher_response_rate_pct',
#  'school_survey_teacher_response_rate_avg_pct',
#  'school_survey_parent_response_rate_pct',
#  'healthy_school_certification',
#  'healthy_school_certification_description',
# ...

# %%
SY2018 = SY2018[["school_id","short_name", "school_type", "primary_category", "phone", 
                 "website", "progress_report_year", "student_growth_rating", "student_attainment_rating", "growth_reading_grades_tested_pct_es",
                 "growth_math_grades_tested_pct_es", "attainment_reading_pct_es", "attainment_math_pct_es", "culture_climate_rating", 
                 "school_survey_involved_families", "school_survey_supportive_environment", "school_survey_ambitious_instruction", 
                 "school_survey_effective_leaders", "school_survey_collaborative_teachers", "school_survey_safety", 
                 "suspensions_per_100_students_avg_pct", "student_attendance_avg_pct", "mobility_rate_pct", "one_year_dropout_rate_year_1_pct",
                 "freshmen_on_track_school_pct_year_1", "college_enrollment_school_pct_year_1", "college_persistence_school_pct_year_2",
                 "teacher_attendance_avg_pct"]]
SY2018["year"]= "2017-18"
len(SY2018)
# Out:
# 661

# %%
SY2019_resp = requests.get("https://data.cityofchicago.org/resource/dw27-rash.json")
SY2019_list = json.loads(SY2019_resp.text)
SY2019 = pd.DataFrame(SY2019_list)
list(SY2019.columns)
# Out:
# ['school_id',
#  'short_name',
#  'long_name',
#  'school_type',
#  'primary_category',
#  'address',
#  'city',
#  'state',
#  'zip',
#  'phone',
#  'fax',
#  'cps_school_profile',
#  'website',
#  'progress_report_year',
#  'student_growth_rating',
#  'student_growth_description',
#  'growth_reading_grades_tested',
#  'growth_reading_grades_tested_1',
#  'growth_math_grades_tested',
#  'growth_math_grades_tested_1',
#  'student_attainment_rating',
#  'student_attainment_description',
#  'attainment_reading_pct_es',
#  'attainment_reading_lbl_es',
#  'attainment_math_pct_es',
#  'attainment_math_lbl_es',
#  'culture_climate_rating',
#  'culture_climate_description',
#  'school_survey_student_response',
#  'school_survey_student_response_1',
#  'school_survey_teacher_response',
#  'school_survey_teacher_response_1',
#  'school_survey_parent_response',
#  'school_survey_parent_response_1',
#  'healthy_school_certification',
#  'healthy_school_certification_1',
# ...

# %%
SY2019 = SY2019[["school_id","short_name", "school_type", "primary_category", "address", "city", "state", "zip", "phone", 
                 "website", "progress_report_year", "student_growth_rating", "student_attainment_rating", "growth_reading_grades_tested",
                 "growth_math_grades_tested", "attainment_reading_pct_es", "attainment_math_pct_es", "culture_climate_rating", 
                 "school_survey_involved", "school_survey_supportive", "school_survey_ambitious", 
                 "school_survey_effective", "school_survey_collaborative", "school_survey_safety", 
                 "suspensions_per_100_students", "student_attendance_avg_pct", "mobility_rate_pct", "one_year_dropout_rate_year_1",
                 "freshmen_on_track_school_1", "college_enrollment_school_1", "college_persistence_school_1",
                 "teacher_attendance_year_1","school_latitude", "school_longitude"]]
SY2019["year"]= "2018-19"
len(SY2019)
# Out:
# 654

# %%
SY2019 = SY2019.rename(columns={"growth_reading_grades_tested":"growth_reading_grades_tested_pct_es", "growth_math_grades_tested":"growth_math_grades_tested_pct_es",
                        "school_survey_involved": "school_survey_involved_families", "school_survey_supportive": "school_survey_supportive_environment",
                        "school_survey_ambitious":"school_survey_ambitious_instruction", "school_survey_effective": "school_survey_effective_leaders",
                        "school_survey_collaborative": "school_survey_collaborative_teachers", "suspensions_per_100_students": "suspensions_per_100_students_avg_pct",
                        "one_year_dropout_rate_year_1": "one_year_dropout_rate_year_1_pct", "freshmen_on_track_school_1": "freshmen_on_track_school_pct_year_1",
                        "freshmen_on_track_school_1": "freshmen_on_track_school_pct_year_1", "college_enrollment_school_1": "college_enrollment_school_pct_year_1",
                        "college_persistence_school_1":"college_persistence_school_pct_year_2", "teacher_attendance_year_1": "teacher_attendance_avg_pct"})
SY2019.head()
# Out:
#   school_id             short_name   school_type primary_category  \
# 0    400116   MONTESSORI ENGLEWOOD       Charter               ES
# 1    400115       CATALYST - MARIA       Charter               ES
# 2    400056  NOBLE - ROWE CLARK HS       Charter               HS
# 3    610588             RICHARDSON  Neighborhood               MS
# 4    610548                   STEM        Magnet               ES
#
#                  address     city     state    zip       phone  \
# 0   6936 S HERMITAGE AVE  Chicago  Illinois  60636  7735359255
# 1  6727 S CALIFORNIA AVE  Chicago  Illinois  60629  7739931770
# 2     3645 W CHICAGO AVE  Chicago  Illinois  60651  7732422212
# 3          6018 S KARLOV  Chicago  Illinois  60629  7735358640
# 4     1522 W FILLMORE ST  Chicago  Illinois  60607  7735347300
#
#                               website  ... student_attendance_avg_pct  \
# 0               https://www.tmsoe.org  ...                       93.3
# ...

# %%
SY2016 = SY2016.rename(columns={"one_year_dropout_rate_avg_pct":"one_year_dropout_rate_year_1_pct"})
SY2016.head()
# Out:
#   school_id           short_name           school_type primary_category  \
# 0    400179  NOBLE - MANSUETO HS               Charter               HS
# 1    610547  SOUTH SHORE INTL HS  Selective enrollment               HS
# 2    400097     NOBLE - BULLS HS               Charter               HS
# 3    610515         DISNEY II ES                Magnet               ES
# 4    609997               HOLMES          Neighborhood               ES
#
#                address     city     state    zip       phone  \
# 0       5101 S KEELER   Chicago  Illinois  60632  7733498200
# 1       1955 E 75TH ST  Chicago  Illinois  60649  7735358351
# 2      2040 W ADAMS ST  Chicago  Illinois  60612  7735347599
# 3   3815 N KEDVALE AVE  Chicago  Illinois  60641  7735343750
# 4  955 W GARFIELD BLVD  Chicago  Illinois  60621  7735359025
#
#   progress_report_year  ... student_attendance_avg_pct mobility_rate_pct  \
# 0                 2015  ...                        NaN               NaN
# ...

# %%
SY2016.dtypes
# Out:
# school_id                                object
# short_name                               object
# school_type                              object
# primary_category                         object
# address                                  object
# city                                     object
# state                                    object
# zip                                      object
# phone                                    object
# progress_report_year                     object
# student_growth_rating                    object
# student_attainment_rating                object
# growth_reading_grades_tested_pct_es      object
# growth_math_grades_tested_pct_es         object
# attainment_reading_pct_es                object
# attainment_math_pct_es                   object
# culture_climate_rating                   object
# school_survey_involved_families          object
# school_survey_supportive_environment     object
# school_survey_ambitious_instruction      object
# ...

# %%
SY2017.dtypes
# Out:
# school_id                                object
# short_name                               object
# school_type                              object
# primary_category                         object
# address                                  object
# city                                     object
# state                                    object
# zip                                      object
# phone                                    object
# website                                  object
# progress_report_year                     object
# student_growth_rating                    object
# student_attainment_rating                object
# growth_reading_grades_tested_pct_es      object
# growth_math_grades_tested_pct_es         object
# attainment_reading_pct_es                object
# attainment_math_pct_es                   object
# culture_climate_rating                   object
# school_survey_involved_families          object
# school_survey_supportive_environment     object
# ...

# %%
SY2018.dtypes
# Out:
# school_id                                object
# short_name                               object
# school_type                              object
# primary_category                         object
# phone                                    object
# website                                  object
# progress_report_year                     object
# student_growth_rating                    object
# student_attainment_rating                object
# growth_reading_grades_tested_pct_es      object
# growth_math_grades_tested_pct_es         object
# attainment_reading_pct_es                object
# attainment_math_pct_es                   object
# culture_climate_rating                   object
# school_survey_involved_families          object
# school_survey_supportive_environment     object
# school_survey_ambitious_instruction      object
# school_survey_effective_leaders          object
# school_survey_collaborative_teachers     object
# school_survey_safety                     object
# ...

# %%
SY2019.dtypes
# Out:
# school_id                                object
# short_name                               object
# school_type                              object
# primary_category                         object
# address                                  object
# city                                     object
# state                                    object
# zip                                      object
# phone                                    object
# website                                  object
# progress_report_year                     object
# student_growth_rating                    object
# student_attainment_rating                object
# growth_reading_grades_tested_pct_es      object
# growth_math_grades_tested_pct_es         object
# attainment_reading_pct_es                object
# attainment_math_pct_es                   object
# culture_climate_rating                   object
# school_survey_involved_families          object
# school_survey_supportive_environment     object
# ...

# %% [markdown]
# ## Send to SQL Server

# %%
db_engine = create_engine('postgresql://postgres:postgres@localhost:5432/CPS_school_data')

# %%
SY2016.to_sql("SY2016", con=db_engine, if_exists="replace")

# %%
SY2017.to_sql("SY2017", con=db_engine, if_exists="replace")

# %%
SY2018.to_sql("SY2018", con=db_engine, if_exists="replace")

# %%
SY2019.to_sql("SY2019", con=db_engine, if_exists="replace")
